# %% [markdown]
# ### Day 09 - Python Basics (Tuples, Sets, Lists, Email Validation)
#
# This notebook covers:
# - Tuples (immutable data)
# - Sets (unique values and set operations)
# - Lists (ordered, mutable sequences)
# - Simple email validation and visitor tracking examples
# - Hashing and performance comparison

# %% [markdown]
#  1. Lists Ordered, Changeable, Allow Duplicates

# %% [markdown]
# 2. Tuples Ordered, Immutable, Fast

# %% [markdown]
# 3. Sets Unordered, Unique, Fast Membership

# %% [markdown]
# ##### Common Errors
# - Tuple cannot be modified
# - Indentation errors
# - KeyboardInterrupt from Ctrl+C
