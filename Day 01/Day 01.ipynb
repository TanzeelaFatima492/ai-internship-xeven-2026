# %% [markdown]
# # 📘 Day 1 - Introduction to Artificial Intelligence
#
# ## AI Engineer Internship - Xeven Solutions
# ### 👩‍💻 Name: Tanzeela Fatima
#
#
# ## 🎯 Objectives
# - Understand Artificial Intelligence (AI)
# - Learn AI types and real-world applications
# - Explore AI fields (ML, DL, NLP, CV)
# - Set up development environment
# - Create first Python project

# %% [markdown]
# # 🧠 What is Artificial Intelligence?
#
# Artificial Intelligence (AI) is a field of computer science that enables machines to perform tasks that normally require human intelligence.
#
# These tasks include:
# - Learning from data
# - Understanding language
# - Recognizing images
# - Making decisions
#
# ## 📜 History
# - 1950: Alan Turing proposed machine intelligence
# - 1956: Dartmouth Conference officially named "Artificial Intelligence"
#
# ## 🌍 Real-World Impact
# - Healthcare: Disease diagnosis
# - Finance: Fraud detection
# - Education: Personalized learning
# - Marketing: Recommendation systems

# %% [markdown]
# # 🤖 Types of AI
#
# ## 1. Narrow AI (Weak AI)
# - Designed for one specific task
# - Used today in real systems
#
# Examples:
# - Siri
# - ChatGPT
# - Google Translate
#
# ## 2. General AI (Strong AI)
# - Future concept
# - Can perform any intellectual task like humans
# - Not yet fully developed

# %% [markdown]
# # 🏢 AI Domains & Applications
#
# ## 🏥 Healthcare
# - Disease diagnosis
# - Medical imaging
#
# ## 💰 Finance
# - Fraud detection
# - Risk analysis
#
# ## 🎓 Education
# - Personalized learning systems
#
# ## 📢 Marketing
# - Recommendation engines (Netflix, YouTube)

# %% [markdown]
# # 🧩 Fields of AI
#
# ## Machine Learning (ML)
# - Learning from data
#
# ## Deep Learning (DL)
# - Neural networks based learning
#
# ## AI Engineering
# - Building and deploying AI systems

# %% [markdown]
# # 🗣️ AI Core Technologies
#
# ## NLP (Natural Language Processing)
# - Understands text
# - Example: Chatbots
#
# ## Speech Recognition
# - Converts voice to text
# - Example: Siri, Alexa
#
# ## Computer Vision
# - Understands images/videos
# - Example: Face recognition

# %% [markdown]
# # ⚙️ Training vs Inference
#
# ## Training
# - Learning from data
# - Builds AI model intelligence
#
# ## Inference
# - Using trained model
# - Making predictions

# %%
print("Hi, this is Tanzeela Fatima, future AI engineer!")

# %% [markdown]
# # 💻 Environment Setup
#
# ## Installed Tools
# - Python 3.11+
# ![image.png](attachment:image.png)
# - VS Code
# ![image-2.png](attachment:image-2.png)
# - Python Extension
# ![image-3.png](attachment:image-3.png)
# - Git & GitHub
# ![image-4.png](attachment:image-4.png)
# - UV Package Manager
#
# ## Virtual Environment
# Virtual environments isolate project dependencies so each project runs independently.
#
# ## Global Environment
# A single Python environment shared across all projects (can cause conflicts).

# %% [markdown]
# # 📊 AI Research Comparison (Day 1 Task)
#
# | Source  | Key Points | Examples | Clarity | Rating |
# |--------|------------|----------|---------|--------|
# | Claude | AI helps in learning and decision-making. Narrow AI works in one domain, while General AI is a future concept that could work like humans across multiple domains. Virtual environments isolate projects to avoid dependency conflicts. AI pillars include NLP, Computer Vision, and Speech Processing. | Traffic management systems, ChatGPT (Narrow AI), NLP (Transformers), Speech systems (Siri), Computer Vision (X-rays, object detection) | Medium | 3 |
# | Gemini | AI includes rule-based systems and learning-based systems. AGI is a future system with human-like intelligence. NLP uses Transformers for understanding language. Speech systems convert audio into spectrograms. Computer Vision uses CNNs and Vision Transformers to process images. Training builds intelligence, inference uses it. | Self-driving cars, facial recognition, text generation, real-time prediction systems | Good | 4 |
# | ChatGPT | AI enables machines to perform human-like tasks such as learning, reasoning, language understanding, and perception. It includes ML, DL, NLP, Speech Recognition, and Computer Vision. Narrow AI is widely used today; General AI is still theoretical. Training = learning from data, inference = making predictions. | ChatGPT, Netflix, Google Maps, spam filters, Siri, Alexa, fraud detection systems | Better | 3 |
# | Medium Article | Introduction to AI, history (Turing, Dartmouth Conference), and real-world applications. AI systems are used in healthcare, finance, education, and marketing. Focus on how AI improves automation and decision-making. | Healthcare diagnosis, fraud detection systems, recommendation engines, chatbots | Good | 4 |
